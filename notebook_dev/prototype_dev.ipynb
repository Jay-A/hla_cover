# %% [markdown]
# # Prototype Development Notebook for HLA Greedy Coverage Solver
#
# ---

# %% [markdown]
# ## 1. Setup and Imports

# %%
import sys
import os

# Go up one directory from notebook_dev to project root (hla_solver_prototype)
project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))

if project_root not in sys.path:
    sys.path.insert(0, project_root)

# Now imports will find hla_solver package
from hla_solver import HLASolver
from hla_solver.preprocessing import preprocess

# %%
import yaml
import pandas as pd
import numpy as np

# %% [markdown]
# ---
# ## 2. Load Config

# %%
# Load YAML configuration for serial run in Jupyter-safe mode
config_path = "../configs/cover_serial_config.yaml"
# config_path = "../configs/cover_thread_pool_config.yaml"
with open(config_path, "r") as f:
    config = yaml.safe_load(f)
for key, value in config.items():
    print(f"{key}: {value}")

# %% [markdown]
# ---
# ## 3. Data Preprocessing

# %%
csv_dataset = config["data"]["dataset_path"]
number_doubles = config["data"].get("number_doubles", 0)

df, hla_groups, allele_to_id, allele_matrix, allele_id_to_positions, allele_columns = preprocess(
    csv_dataset,
    number_doubles,
    verbose=True
)

# %% [markdown]
# ---
# ## 4. Instantiate Solver

# %%
solver = HLASolver(config_path)

# %% [markdown]
# ---
# ## 5. Run Solver

# %%
import sys
import os

# Optional: import time if your run is long and you want timestamps
from datetime import datetime

class Tee:
    def __init__(self, *streams):
        self.streams = streams

    def write(self, message):
        for s in self.streams:
            s.write(message)
            s.flush()  # Ensure real-time logging

    def flush(self):
        for s in self.streams:
            s.flush()

# Set up project root path
project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))
if project_root not in sys.path:
    sys.path.insert(0, project_root)

from hla_solver import HLASolver

# Path to config file
config_path = os.path.join(project_root, "configs", "cover_serial_config.yaml")
solver = HLASolver(config_path)

# Define log file path
log_path = os.path.join(project_root, "console_output_serial_test.log")

# Open log file and tee stdout to both console and log
with open(log_path, "w", encoding="utf-8") as logfile:
    tee = Tee(sys.stdout, logfile)
    sys.stdout = tee  # Override stdout
    try:
        best_filters = solver.run()
    finally:
        sys.stdout = sys.__stdout__  # Restore original stdout

# Final summary printed to notebook only
print("\nBest filters:", best_filters)
# Out:
# --- START [Preprocessing Dataset] ---
# Loading dataset from ../data/simulated_HLA_samples_5000.csv...
# [Timing] Load dataset: 0.0160 seconds
# Dataset loaded: 5000 samples, 13 columns
# [Timing] Detect allele columns: 0.0000 seconds
# Identified allele columns: ['HLA-A 1', 'HLA-A 2', 'HLA-B 1', 'HLA-B 2', 'HLA-C 1', 'HLA-C 2', 'HLA-DQB1 1', 'HLA-DQB1 2', 'HLA-DRB1 1', 'HLA-DRB1 2']
# [Timing] Truncate alleles: 0.0580 seconds
# [Timing] Index alleles: 0.0060 seconds
# [Timing] Build allele matrix: 0.3740 seconds
# [Timing] Group HLA columns: 0.0000 seconds
# HLA groups identified: [('HLA-A', 'HLA-A 1', 'HLA-A 2'), ('HLA-B', 'HLA-B 1', 'HLA-B 2'), ('HLA-C', 'HLA-C 1', 'HLA-C 2'), ('HLA-DQB', 'HLA-DQB1 1', 'HLA-DQB1 2'), ('HLA-DRB', 'HLA-DRB1 1', 'HLA-DRB1 2')]
# [Timing] Validate/coerce alleles: 0.0010 seconds
# [Timing] Data duplication (augmentation): 0.0000 seconds
# [Timing] Build sample allele sets: 0.3930 seconds
# --- END [Preprocessing Dataset] | Time: 0.87s ---
# [Preprocessing] Completed. Total samples: 5000
# [Preprocessing] HLA Groups: [('HLA-A', 'HLA-A 1', 'HLA-A 2'), ('HLA-B', 'HLA-B 1', 'HLA-B 2'), ('HLA-C', 'HLA-C 1', 'HLA-C 2'), ('HLA-DQB', 'HLA-DQB1 1', 'HLA-DQB1 2'), ('HLA-DRB', 'HLA-DRB1 1', 'HLA-DRB1 2')]
# [Preprocessing] Allele columns: ['HLA-A 1', 'HLA-A 2', 'HLA-B 1', 'HLA-B 2', 'HLA-C 1', 'HLA-C 2', 'HLA-DQB1 1', 'HLA-DQB1 2', 'HLA-DRB1 1', 'HLA-DRB1 2']
# [Preprocessing] Sample allele sets keys: ['SIM_1', 'SIM_2', 'SIM_3']
# [Timing] Preprocessing: 0.8820 seconds
# [BackendManager] Starting new run. Restart path: D:\MoreBackupStuff\Desktop\GoogleDriveLocal\WillemThing\ParallelCoverPrototype\restarts\greedy_restart_serial_20251017_050001.csv
# [Timing] BackendManager setup: 0.0020 seconds
#
# [BackendManager] Running in serial mode.
# [BackendManager] Running in SERIAL mode
#
# --- START [Greedy HLA Coverage (Fast)] ---
#  restart_path: D:\MoreBackupStuff\Desktop\GoogleDriveLocal\WillemThing\ParallelCoverPrototype\restarts\greedy_restart_serial_20251017_050001.csv
# [Restart] Loaded 0 samples from: D:\MoreBackupStuff\Desktop\GoogleDriveLocal\WillemThing\ParallelCoverPrototype\restarts\greedy_restart_serial_20251017_050001.csv
# [multi_sample_coverage_and_remainder] No sample IDs provided.
#
# [Iteration 1] Searching top-3 filters on 5000 samples...
# Processed 5000/5000 samples... ETA ~ 00:00:00
# Completed all samples in 19s
# (1) Sample ID: SIM_3100 — Coverage: 1.28%
# (2) Sample ID: SIM_1495 — Coverage: 1.08%
# (3) Sample ID: SIM_2701 — Coverage: 1.08%
# [Selected] Sample SIM_3100 with estimated coverage 1.28% (full), 1.28% (subset)
#
# [multi_sample_coverage_and_remainder] Sample IDs used: ['SIM_3100']
#   ➤ Coverage type: INTERSECTION (at least one allele in all groups)
#   ➤ Combined dataset coverage: 1.3% (65 of 5000 samples)
#   ➤ Allele IDs used by group:
#     HLA-A: [98, 176]
#     HLA-B: [227, 270]
#     HLA-C: [1, 86]
#     HLA-DQB: [96, 111]
#     HLA-DRB: [1, 59]
# [Restart] Saved restart state to: D:\MoreBackupStuff\Desktop\GoogleDriveLocal\WillemThing\ParallelCoverPrototype\restarts\greedy_restart_serial_20251017_050001.csv
# [Info] Accumulated 1 Sample IDs:
#     ['SIM_3100']
# [Info] Total data set coverage: 1.3%
# [Info] Remaining uncovered samples: 4935
#
# [Iteration 2] Searching top-3 filters on 4935 samples...
# Processed 5000/4935 samples... ETA ~ 00:00:00
# Completed all samples in 19s
# (1) Sample ID: SIM_1495 — Coverage: 1.03%
# (2) Sample ID: SIM_3665 — Coverage: 0.87%
# (3) Sample ID: SIM_3853 — Coverage: 0.85%
# [Selected] Sample SIM_1495 with estimated coverage 1.08% (full), 1.03% (subset)
#
# [multi_sample_coverage_and_remainder] Sample IDs used: ['SIM_3100', 'SIM_1495']
#   ➤ Coverage type: INTERSECTION (at least one allele in all groups)
#   ➤ Combined dataset coverage: 2.34% (117 of 5000 samples)
#   ➤ Allele IDs used by group:
#     HLA-A: [12, 98, 176]
#     HLA-B: [227, 242, 270]
#     HLA-C: [1, 30, 86]
#     HLA-DQB: [27, 96, 111]
#     HLA-DRB: [1, 28, 59, 64]
# [Restart] Saved restart state to: D:\MoreBackupStuff\Desktop\GoogleDriveLocal\WillemThing\ParallelCoverPrototype\restarts\greedy_restart_serial_20251017_050001.csv
# [Info] Accumulated 2 Sample IDs:
#     ['SIM_3100', 'SIM_1495']
# [Info] Total data set coverage: 2.34%
# [Info] Remaining uncovered samples: 4883
#
# [Iteration 3] Searching top-3 filters on 4883 samples...
# Processed 5000/4883 samples... ETA ~ 00:00:00
# Completed all samples in 18s
# (1) Sample ID: SIM_3665 — Coverage: 0.84%
# (2) Sample ID: SIM_3853 — Coverage: 0.8%
# (3) Sample ID: SIM_3009 — Coverage: 0.76%
# [Selected] Sample SIM_3665 with estimated coverage 0.94% (full), 0.84% (subset)
#
# [multi_sample_coverage_and_remainder] Sample IDs used: ['SIM_3100', 'SIM_1495', 'SIM_3665']
#   ➤ Coverage type: INTERSECTION (at least one allele in all groups)
#   ➤ Combined dataset coverage: 3.18% (159 of 5000 samples)
#   ➤ Allele IDs used by group:
#     HLA-A: [9, 12, 98, 176]
#     HLA-B: [227, 242, 270]
#     HLA-C: [1, 28, 30, 74, 86]
#     HLA-DQB: [27, 96, 111, 139]
#     HLA-DRB: [1, 2, 28, 59, 64]
# [Restart] Saved restart state to: D:\MoreBackupStuff\Desktop\GoogleDriveLocal\WillemThing\ParallelCoverPrototype\restarts\greedy_restart_serial_20251017_050001.csv
# [Info] Accumulated 3 Sample IDs:
#     ['SIM_3100', 'SIM_1495', 'SIM_3665']
# [Info] Total data set coverage: 3.18%
# [Info] Remaining uncovered samples: 4841
#
# [Iteration 4] Searching top-3 filters on 4841 samples...
# Processed 5000/4841 samples... ETA ~ 00:00:00
# Completed all samples in 18s
# (1) Sample ID: SIM_3853 — Coverage: 0.74%
# (2) Sample ID: SIM_4754 — Coverage: 0.66%
# (3) Sample ID: SIM_3448 — Coverage: 0.64%
# [Selected] Sample SIM_3853 with estimated coverage 0.9% (full), 0.74% (subset)
#
# [multi_sample_coverage_and_remainder] Sample IDs used: ['SIM_3100', 'SIM_1495', 'SIM_3665', 'SIM_3853']
#   ➤ Coverage type: INTERSECTION (at least one allele in all groups)
#   ➤ Combined dataset coverage: 3.92% (196 of 5000 samples)
#   ➤ Allele IDs used by group:
#     HLA-A: [7, 9, 12, 98, 176]
#     HLA-B: [118, 140, 227, 242, 270]
#     HLA-C: [1, 28, 30, 74, 86]
#     HLA-DQB: [27, 96, 111, 139]
#     HLA-DRB: [1, 2, 28, 59, 64]
# [Restart] Saved restart state to: D:\MoreBackupStuff\Desktop\GoogleDriveLocal\WillemThing\ParallelCoverPrototype\restarts\greedy_restart_serial_20251017_050001.csv
# [Info] Accumulated 4 Sample IDs:
#     ['SIM_3100', 'SIM_1495', 'SIM_3665', 'SIM_3853']
# [Info] Total data set coverage: 3.92%
# [Info] Remaining uncovered samples: 4804
#
# [Iteration 5] Searching top-3 filters on 4804 samples...
# Processed 5000/4804 samples... ETA ~ 00:00:00
# Completed all samples in 18s
# (1) Sample ID: SIM_3448 — Coverage: 0.65%
# (2) Sample ID: SIM_201 — Coverage: 0.6%
# (3) Sample ID: SIM_1212 — Coverage: 0.6%
# [Selected] Sample SIM_3448 with estimated coverage 0.62% (full), 0.65% (subset)
#
# [multi_sample_coverage_and_remainder] Sample IDs used: ['SIM_3100', 'SIM_1495', 'SIM_3665', 'SIM_3853', 'SIM_3448']
#   ➤ Coverage type: INTERSECTION (at least one allele in all groups)
#   ➤ Combined dataset coverage: 4.56% (228 of 5000 samples)
#   ➤ Allele IDs used by group:
#     HLA-A: [0, 7, 9, 12, 98, 176]
#     HLA-B: [74, 118, 140, 172, 227, 242, 270]
#     HLA-C: [1, 28, 30, 43, 74, 86]
#     HLA-DQB: [0, 27, 46, 96, 111, 139]
#     HLA-DRB: [1, 2, 27, 28, 59, 64, 65]
# [Restart] Saved restart state to: D:\MoreBackupStuff\Desktop\GoogleDriveLocal\WillemThing\ParallelCoverPrototype\restarts\greedy_restart_serial_20251017_050001.csv
# [Info] Accumulated 5 Sample IDs:
#     ['SIM_3100', 'SIM_1495', 'SIM_3665', 'SIM_3853', 'SIM_3448']
# [Info] Total data set coverage: 4.56%
# [Info] Remaining uncovered samples: 4772
#
# [Iteration 6] Searching top-3 filters on 4772 samples...
# Processed 5000/4772 samples... ETA ~ 00:00:00
# Completed all samples in 17s
# (1) Sample ID: SIM_1212 — Coverage: 0.61%
# (2) Sample ID: SIM_1252 — Coverage: 0.57%
# (3) Sample ID: SIM_2694 — Coverage: 0.57%
# [Selected] Sample SIM_1212 with estimated coverage 0.74% (full), 0.61% (subset)
#
# [multi_sample_coverage_and_remainder] Sample IDs used: ['SIM_3100', 'SIM_1495', 'SIM_3665', 'SIM_3853', 'SIM_3448', 'SIM_1212']
#   ➤ Coverage type: INTERSECTION (at least one allele in all groups)
#   ➤ Combined dataset coverage: 5.16% (258 of 5000 samples)
#   ➤ Allele IDs used by group:
#     HLA-A: [0, 7, 9, 12, 98, 176, 208]
#     HLA-B: [74, 118, 140, 172, 227, 242, 270]
#     HLA-C: [1, 28, 30, 43, 74, 86]
#     HLA-DQB: [0, 27, 46, 96, 111, 139]
#     HLA-DRB: [1, 2, 27, 28, 59, 64, 65]
# [Restart] Saved restart state to: D:\MoreBackupStuff\Desktop\GoogleDriveLocal\WillemThing\ParallelCoverPrototype\restarts\greedy_restart_serial_20251017_050001.csv
# [Info] Accumulated 6 Sample IDs:
#     ['SIM_3100', 'SIM_1495', 'SIM_3665', 'SIM_3853', 'SIM_3448', 'SIM_1212']
# [Info] Total data set coverage: 5.16%
# [Info] Remaining uncovered samples: 4742
#
# [Iteration 7] Searching top-3 filters on 4742 samples...
# Processed 5000/4742 samples... ETA ~ 00:00:00
# Completed all samples in 17s
# (1) Sample ID: SIM_2694 — Coverage: 0.57%
# (2) Sample ID: SIM_201 — Coverage: 0.55%
# (3) Sample ID: SIM_4043 — Coverage: 0.53%
# [Selected] Sample SIM_2694 with estimated coverage 0.54% (full), 0.57% (subset)
#
# [multi_sample_coverage_and_remainder] Sample IDs used: ['SIM_3100', 'SIM_1495', 'SIM_3665', 'SIM_3853', 'SIM_3448', 'SIM_1212', 'SIM_2694']
#   ➤ Coverage type: INTERSECTION (at least one allele in all groups)
#   ➤ Combined dataset coverage: 5.72% (286 of 5000 samples)
#   ➤ Allele IDs used by group:
#     HLA-A: [0, 7, 9, 12, 27, 98, 176, 208]
#     HLA-B: [74, 118, 140, 172, 227, 242, 249, 270]
#     HLA-C: [1, 28, 30, 43, 65, 74, 86, 112]
#     HLA-DQB: [0, 27, 46, 73, 96, 111, 139]
#     HLA-DRB: [1, 2, 27, 28, 55, 59, 64, 65]
# [Restart] Saved restart state to: D:\MoreBackupStuff\Desktop\GoogleDriveLocal\WillemThing\ParallelCoverPrototype\restarts\greedy_restart_serial_20251017_050001.csv
# [Info] Accumulated 7 Sample IDs:
#     ['SIM_3100', 'SIM_1495', 'SIM_3665', 'SIM_3853', 'SIM_3448', 'SIM_1212', 'SIM_2694']
# [Info] Total data set coverage: 5.72%
# [Info] Remaining uncovered samples: 4714
#
# [Iteration 8] Searching top-3 filters on 4714 samples...
# Processed 5000/4714 samples... ETA ~ 00:00:00
# Completed all samples in 17s
# (1) Sample ID: SIM_4504 — Coverage: 0.53%
# (2) Sample ID: SIM_3538 — Coverage: 0.51%
# (3) Sample ID: SIM_3683 — Coverage: 0.51%
# [Selected] Sample SIM_4504 with estimated coverage 0.62% (full), 0.53% (subset)
#
# [multi_sample_coverage_and_remainder] Sample IDs used: ['SIM_3100', 'SIM_1495', 'SIM_3665', 'SIM_3853', 'SIM_3448', 'SIM_1212', 'SIM_2694', 'SIM_4504']
#   ➤ Coverage type: INTERSECTION (at least one allele in all groups)
#   ➤ Combined dataset coverage: 6.24% (312 of 5000 samples)
#   ➤ Allele IDs used by group:
#     HLA-A: [0, 7, 9, 12, 27, 98, 176, 208]
#     HLA-B: [74, 118, 140, 172, 227, 242, 249, 270]
#     HLA-C: [1, 28, 30, 43, 65, 74, 86, 112]
#     HLA-DQB: [0, 27, 46, 73, 96, 111, 139]
#     HLA-DRB: [1, 2, 3, 27, 28, 55, 59, 64, 65]
# [Restart] Saved restart state to: D:\MoreBackupStuff\Desktop\GoogleDriveLocal\WillemThing\ParallelCoverPrototype\restarts\greedy_restart_serial_20251017_050001.csv
# [Info] Accumulated 8 Sample IDs:
#     ['SIM_3100', 'SIM_1495', 'SIM_3665', 'SIM_3853', 'SIM_3448', 'SIM_1212', 'SIM_2694', 'SIM_4504']
# [Info] Total data set coverage: 6.24%
# [Info] Remaining uncovered samples: 4688
#
# [Iteration 9] Searching top-3 filters on 4688 samples...
# Processed 5000/4688 samples... ETA ~ -1:59:59
# Completed all samples in 17s
# (1) Sample ID: SIM_3538 — Coverage: 0.51%
# (2) Sample ID: SIM_4548 — Coverage: 0.51%
# (3) Sample ID: SIM_670 — Coverage: 0.49%
# [Selected] Sample SIM_3538 with estimated coverage 0.64% (full), 0.51% (subset)
#
# [multi_sample_coverage_and_remainder] Sample IDs used: ['SIM_3100', 'SIM_1495', 'SIM_3665', 'SIM_3853', 'SIM_3448', 'SIM_1212', 'SIM_2694', 'SIM_4504', 'SIM_3538']
#   ➤ Coverage type: INTERSECTION (at least one allele in all groups)
#   ➤ Combined dataset coverage: 6.74% (337 of 5000 samples)
#   ➤ Allele IDs used by group:
#     HLA-A: [0, 7, 9, 12, 27, 98, 176, 208]
#     HLA-B: [74, 118, 140, 172, 227, 242, 249, 270]
#     HLA-C: [1, 28, 30, 43, 65, 74, 86, 112]
#     HLA-DQB: [0, 27, 46, 73, 96, 111, 139, 168]
#     HLA-DRB: [1, 2, 3, 27, 28, 55, 59, 64, 65]
# [Restart] Saved restart state to: D:\MoreBackupStuff\Desktop\GoogleDriveLocal\WillemThing\ParallelCoverPrototype\restarts\greedy_restart_serial_20251017_050001.csv
# [Info] Accumulated 9 Sample IDs:
#     ['SIM_3100', 'SIM_1495', 'SIM_3665', 'SIM_3853', 'SIM_3448', 'SIM_1212', 'SIM_2694', 'SIM_4504', 'SIM_3538']
# [Info] Total data set coverage: 6.74%
# [Info] Remaining uncovered samples: 4663
#
# [Iteration 10] Searching top-3 filters on 4663 samples...
# Processed 5000/4663 samples... ETA ~ -1:59:59
# Completed all samples in 17s
# (1) Sample ID: SIM_4548 — Coverage: 0.51%
# (2) Sample ID: SIM_670 — Coverage: 0.49%
# (3) Sample ID: SIM_1425 — Coverage: 0.49%
# [Selected] Sample SIM_4548 with estimated coverage 0.54% (full), 0.51% (subset)
#
# [multi_sample_coverage_and_remainder] Sample IDs used: ['SIM_3100', 'SIM_1495', 'SIM_3665', 'SIM_3853', 'SIM_3448', 'SIM_1212', 'SIM_2694', 'SIM_4504', 'SIM_3538', 'SIM_4548']
#   ➤ Coverage type: INTERSECTION (at least one allele in all groups)
#   ➤ Combined dataset coverage: 7.24% (362 of 5000 samples)
#   ➤ Allele IDs used by group:
#     HLA-A: [0, 7, 9, 12, 27, 98, 176, 185, 208]
#     HLA-B: [74, 118, 140, 172, 191, 227, 242, 249, 270]
#     HLA-C: [1, 28, 30, 43, 65, 73, 74, 86, 112]
#     HLA-DQB: [0, 27, 46, 73, 96, 111, 139, 167, 168]
#     HLA-DRB: [1, 2, 3, 27, 28, 55, 59, 64, 65]
# [Restart] Saved restart state to: D:\MoreBackupStuff\Desktop\GoogleDriveLocal\WillemThing\ParallelCoverPrototype\restarts\greedy_restart_serial_20251017_050001.csv
# [Info] Accumulated 10 Sample IDs:
#     ['SIM_3100', 'SIM_1495', 'SIM_3665', 'SIM_3853', 'SIM_3448', 'SIM_1212', 'SIM_2694', 'SIM_4504', 'SIM_3538', 'SIM_4548']
# [Info] Total data set coverage: 7.24%
# [Info] Remaining uncovered samples: 4638
#
# [Iteration 11] Searching top-3 filters on 4638 samples...
# Processed 4900/4638 samples... ETA ~ 00:00:00
# Completed all samples in 16s
# (1) Sample ID: SIM_670 — Coverage: 0.5%
# (2) Sample ID: SIM_1425 — Coverage: 0.5%
# (3) Sample ID: SIM_168 — Coverage: 0.45%
# [Selected] Sample SIM_670 with estimated coverage 0.46% (full), 0.5% (subset)
#
# [multi_sample_coverage_and_remainder] Sample IDs used: ['SIM_3100', 'SIM_1495', 'SIM_3665', 'SIM_3853', 'SIM_3448', 'SIM_1212', 'SIM_2694', 'SIM_4504', 'SIM_3538', 'SIM_4548', 'SIM_670']
#   ➤ Coverage type: INTERSECTION (at least one allele in all groups)
#   ➤ Combined dataset coverage: 7.72% (386 of 5000 samples)
#   ➤ Allele IDs used by group:
#     HLA-A: [0, 7, 9, 12, 27, 98, 176, 185, 208]
#     HLA-B: [74, 86, 118, 140, 172, 191, 227, 242, 249, 270]
#     HLA-C: [1, 28, 30, 43, 65, 73, 74, 86, 112]
#     HLA-DQB: [0, 27, 46, 73, 96, 111, 139, 167, 168]
#     HLA-DRB: [1, 2, 3, 8, 27, 28, 55, 59, 64, 65]
# [Restart] Saved restart state to: D:\MoreBackupStuff\Desktop\GoogleDriveLocal\WillemThing\ParallelCoverPrototype\restarts\greedy_restart_serial_20251017_050001.csv
# [Info] Accumulated 11 Sample IDs:
#     ['SIM_3100', 'SIM_1495', 'SIM_3665', 'SIM_3853', 'SIM_3448', 'SIM_1212', 'SIM_2694', 'SIM_4504', 'SIM_3538', 'SIM_4548', 'SIM_670']
# [Info] Total data set coverage: 7.72%
# [Info] Remaining uncovered samples: 4614
#
# [Iteration 12] Searching top-3 filters on 4614 samples...
# Processed 4900/4614 samples... ETA ~ 00:00:00
# Completed all samples in 16s
# (1) Sample ID: SIM_1425 — Coverage: 0.5%
# (2) Sample ID: SIM_168 — Coverage: 0.46%
# (3) Sample ID: SIM_4075 — Coverage: 0.46%
# [Selected] Sample SIM_1425 with estimated coverage 0.46% (full), 0.5% (subset)
#
# [multi_sample_coverage_and_remainder] Sample IDs used: ['SIM_3100', 'SIM_1495', 'SIM_3665', 'SIM_3853', 'SIM_3448', 'SIM_1212', 'SIM_2694', 'SIM_4504', 'SIM_3538', 'SIM_4548', 'SIM_670', 'SIM_1425']
#   ➤ Coverage type: INTERSECTION (at least one allele in all groups)
#   ➤ Combined dataset coverage: 8.2% (410 of 5000 samples)
#   ➤ Allele IDs used by group:
#     HLA-A: [0, 7, 9, 12, 27, 98, 176, 185, 208]
#     HLA-B: [74, 86, 118, 140, 172, 191, 213, 227, 237, 242, 249, 270]
#     HLA-C: [1, 28, 30, 43, 65, 73, 74, 86, 112]
#     HLA-DQB: [0, 27, 46, 73, 96, 111, 139, 167, 168]
#     HLA-DRB: [1, 2, 3, 8, 27, 28, 55, 59, 64, 65]
# [Restart] Saved restart state to: D:\MoreBackupStuff\Desktop\GoogleDriveLocal\WillemThing\ParallelCoverPrototype\restarts\greedy_restart_serial_20251017_050001.csv
# [Info] Accumulated 12 Sample IDs:
#     ['SIM_3100', 'SIM_1495', 'SIM_3665', 'SIM_3853', 'SIM_3448', 'SIM_1212', 'SIM_2694', 'SIM_4504', 'SIM_3538', 'SIM_4548', 'SIM_670', 'SIM_1425']
# [Info] Total data set coverage: 8.2%
# [Info] Remaining uncovered samples: 4590
#
# [Iteration 13] Searching top-3 filters on 4590 samples...
# Processed 4900/4590 samples... ETA ~ -1:59:59
# Completed all samples in 16s
# (1) Sample ID: SIM_168 — Coverage: 0.46%
# (2) Sample ID: SIM_288 — Coverage: 0.44%
# (3) Sample ID: SIM_2833 — Coverage: 0.44%
# [Selected] Sample SIM_168 with estimated coverage 0.54% (full), 0.46% (subset)
#
# [multi_sample_coverage_and_remainder] Sample IDs used: ['SIM_3100', 'SIM_1495', 'SIM_3665', 'SIM_3853', 'SIM_3448', 'SIM_1212', 'SIM_2694', 'SIM_4504', 'SIM_3538', 'SIM_4548', 'SIM_670', 'SIM_1425', 'SIM_168']
#   ➤ Coverage type: INTERSECTION (at least one allele in all groups)
#   ➤ Combined dataset coverage: 8.64% (432 of 5000 samples)
#   ➤ Allele IDs used by group:
#     HLA-A: [0, 7, 9, 12, 27, 98, 176, 185, 208]
#     HLA-B: [74, 86, 118, 140, 172, 191, 213, 227, 237, 242, 249, 270]
#     HLA-C: [1, 28, 30, 43, 65, 73, 74, 86, 112]
#     HLA-DQB: [0, 27, 46, 73, 96, 111, 139, 167, 168]
#     HLA-DRB: [0, 1, 2, 3, 8, 27, 28, 55, 59, 64, 65]
# [Restart] Saved restart state to: D:\MoreBackupStuff\Desktop\GoogleDriveLocal\WillemThing\ParallelCoverPrototype\restarts\greedy_restart_serial_20251017_050001.csv
# [Info] Accumulated 13 Sample IDs:
#     ['SIM_3100', 'SIM_1495', 'SIM_3665', 'SIM_3853', 'SIM_3448', 'SIM_1212', 'SIM_2694', 'SIM_4504', 'SIM_3538', 'SIM_4548', 'SIM_670', 'SIM_1425', 'SIM_168']
# [Info] Total data set coverage: 8.64%
# [Info] Remaining uncovered samples: 4568
#
# [Iteration 14] Searching top-3 filters on 4568 samples...
# Processed 4900/4568 samples... ETA ~ -1:59:59
# Completed all samples in 18s
# (1) Sample ID: SIM_2833 — Coverage: 0.44%
# (2) Sample ID: SIM_4075 — Coverage: 0.44%
# (3) Sample ID: SIM_289 — Coverage: 0.42%
# [Selected] Sample SIM_2833 with estimated coverage 0.44% (full), 0.44% (subset)
#
# [multi_sample_coverage_and_remainder] Sample IDs used: ['SIM_3100', 'SIM_1495', 'SIM_3665', 'SIM_3853', 'SIM_3448', 'SIM_1212', 'SIM_2694', 'SIM_4504', 'SIM_3538', 'SIM_4548', 'SIM_670', 'SIM_1425', 'SIM_168', 'SIM_2833']
#   ➤ Coverage type: INTERSECTION (at least one allele in all groups)
#   ➤ Combined dataset coverage: 9.06% (453 of 5000 samples)
#   ➤ Allele IDs used by group:
#     HLA-A: [0, 7, 9, 12, 27, 98, 176, 185, 208]
#     HLA-B: [74, 86, 118, 139, 140, 172, 191, 213, 227, 237, 242, 249, 270]
#     HLA-C: [1, 28, 30, 43, 65, 73, 74, 86, 112]
#     HLA-DQB: [0, 27, 46, 73, 96, 111, 118, 139, 167, 168]
#     HLA-DRB: [0, 1, 2, 3, 7, 8, 27, 28, 55, 59, 64, 65]
# [Restart] Saved restart state to: D:\MoreBackupStuff\Desktop\GoogleDriveLocal\WillemThing\ParallelCoverPrototype\restarts\greedy_restart_serial_20251017_050001.csv
# [Info] Accumulated 14 Sample IDs:
#     ['SIM_3100', 'SIM_1495', 'SIM_3665', 'SIM_3853', 'SIM_3448', 'SIM_1212', 'SIM_2694', 'SIM_4504', 'SIM_3538', 'SIM_4548', 'SIM_670', 'SIM_1425', 'SIM_168', 'SIM_2833']
# [Info] Total data set coverage: 9.06%
# [Info] Remaining uncovered samples: 4547
#
# [Iteration 15] Searching top-3 filters on 4547 samples...
# Processed 4900/4547 samples... ETA ~ -1:59:59
# Completed all samples in 18s
# (1) Sample ID: SIM_4075 — Coverage: 0.44%
# (2) Sample ID: SIM_289 — Coverage: 0.42%
# (3) Sample ID: SIM_509 — Coverage: 0.42%
# [Selected] Sample SIM_4075 with estimated coverage 0.44% (full), 0.44% (subset)
#
# [multi_sample_coverage_and_remainder] Sample IDs used: ['SIM_3100', 'SIM_1495', 'SIM_3665', 'SIM_3853', 'SIM_3448', 'SIM_1212', 'SIM_2694', 'SIM_4504', 'SIM_3538', 'SIM_4548', 'SIM_670', 'SIM_1425', 'SIM_168', 'SIM_2833', 'SIM_4075']
#   ➤ Coverage type: INTERSECTION (at least one allele in all groups)
#   ➤ Combined dataset coverage: 9.48% (474 of 5000 samples)
#   ➤ Allele IDs used by group:
#     HLA-A: [0, 7, 9, 12, 27, 98, 176, 185, 208]
#     HLA-B: [74, 86, 118, 139, 140, 172, 191, 213, 227, 236, 237, 242, 249, 270]
#     HLA-C: [1, 28, 30, 43, 65, 73, 74, 86, 112]
#     HLA-DQB: [0, 27, 46, 73, 96, 111, 118, 139, 167, 168]
#     HLA-DRB: [0, 1, 2, 3, 7, 8, 27, 28, 55, 59, 64, 65, 66]
# [Restart] Saved restart state to: D:\MoreBackupStuff\Desktop\GoogleDriveLocal\WillemThing\ParallelCoverPrototype\restarts\greedy_restart_serial_20251017_050001.csv
# [Info] Accumulated 15 Sample IDs:
#     ['SIM_3100', 'SIM_1495', 'SIM_3665', 'SIM_3853', 'SIM_3448', 'SIM_1212', 'SIM_2694', 'SIM_4504', 'SIM_3538', 'SIM_4548', 'SIM_670', 'SIM_1425', 'SIM_168', 'SIM_2833', 'SIM_4075']
# [Info] Total data set coverage: 9.48%
# [Info] Remaining uncovered samples: 4526
# --- END [Greedy HLA Coverage (Fast)] | Time: 268.82s ---
# [Timing] serial::greedy_hla_coverage: 268.8205 seconds
# Selected Samples: ['SIM_3100', 'SIM_1495', 'SIM_3665', 'SIM_3853', 'SIM_3448', 'SIM_1212', 'SIM_2694', 'SIM_4504', 'SIM_3538', 'SIM_4548', 'SIM_670', 'SIM_1425', 'SIM_168', 'SIM_2833', 'SIM_4075']
# Filters: [{'HLA-A': [98, 176], 'HLA-B': [227, 270], 'HLA-C': [1, 86], 'HLA-DQB': [96, 111], 'HLA-DRB': [1, 59]}, {'HLA-A': [12, 98], 'HLA-B': [227, 242], 'HLA-C': [30, 86], 'HLA-DQB': [27, 96], 'HLA-DRB': [28, 64]}, {'HLA-A': [9, 98], 'HLA-B': [227, 242], 'HLA-C': [28, 74], 'HLA-DQB': [111, 139], 'HLA-DRB': [2, 28]}, {'HLA-A': [7, 98], 'HLA-B': [118, 140], 'HLA-C': [1, 86], 'HLA-DQB': [96, 111], 'HLA-DRB': [2, 28]}, {'HLA-A': [0, 7], 'HLA-B': [74, 172], 'HLA-C': [43, 74], 'HLA-DQB': [0, 46], 'HLA-DRB': [27, 65]}, {'HLA-A': [12, 208], 'HLA-B': [140, 242], 'HLA-C': [1, 28], 'HLA-DQB': [96, 111], 'HLA-DRB': [1, 28]}, {'HLA-A': [0, 27], 'HLA-B': [74, 249], 'HLA-C': [65, 112], 'HLA-DQB': [73, 139], 'HLA-DRB': [27, 55]}, {'HLA-A': [12, 98], 'HLA-B': [140, 227], 'HLA-C': [1, 86], 'HLA-DQB': [111, 139], 'HLA-DRB': [3, 55]}, {'HLA-A': [98, 176], 'HLA-B': [227, 242], 'HLA-C': [28, 74], 'HLA-DQB': [96, 168], 'HLA-DRB': [27, 64]}, {'HLA-A': [7, 185], 'HLA-B': [74, 191], 'HLA-C': [73, 74], 'HLA-DQB': [139, 167], 'HLA-DRB': [27, 28]}, {'HLA-A': [7, 176], 'HLA-B': [86, 191], 'HLA-C': [65, 73], 'HLA-DQB': [0, 73], 'HLA-DRB': [8, 55]}, {'HLA-A': [0, 7], 'HLA-B': [213, 237], 'HLA-C': [43, 74], 'HLA-DQB': [27, 73], 'HLA-DRB': [27, 64]}, {'HLA-A': [98], 'HLA-B': [140, 270], 'HLA-C': [43, 74], 'HLA-DQB': [96, 111], 'HLA-DRB': [0, 28]}, {'HLA-A': [7, 176], 'HLA-B': [74, 139], 'HLA-C': [43, 65], 'HLA-DQB': [73, 118], 'HLA-DRB': [7, 65]}, {'HLA-A': [0, 27], 'HLA-B': [86, 236], 'HLA-C': [43, 65], 'HLA-DQB': [73, 139], 'HLA-DRB': [27, 66]}]
# remainder:                Region Population Sample ID HLA-A 1 HLA-A 2 HLA-B 1 HLA-B 2  \
# 0     North-East Asia    unknown     SIM_1   23:01   68:01   27:02   07:02
# 1     North-East Asia    unknown     SIM_2   03:01   01:01   08:01   07:02
# 2          South Asia    unknown     SIM_3   02:01   33:03   52:01   35:03
# 3          South Asia    unknown     SIM_4   68:01   01:01   49:01   07:02
# 4     South-East Asia   Oriental     SIM_5   33:03   33:03   51:01   13:01
# ...               ...        ...       ...     ...     ...     ...     ...
# 4991  North-East Asia    unknown  SIM_4992   01:01   02:01   13:02   44:02
# 4992       South Asia    unknown  SIM_4993   11:01   24:02   27:05   40:06
# 4995       South Asia    unknown  SIM_4996   33:03   01:01   35:01   15:17
# 4997       South Asia    unknown  SIM_4998   01:01   24:02   50:01   40:06
# 4998  North-East Asia    unknown  SIM_4999   02:01   03:01   35:01   41:02
#
#      HLA-C 1 HLA-C 2 HLA-DQB1 1 HLA-DQB1 2 HLA-DRB1 1 HLA-DRB1 2
# 0      07:02   01:02      03:01      01:01      03:01      05:01
# 1      07:01   01:02      04:02      14:04      02:02      05:01
# 2      15:02   04:01      12:02      11:01      06:01      02:02
# 3      15:02   07:02      11:01      07:01      05:03      06:01
# 4      14:02   08:01      09:01      15:01      06:01      03:02
# ...      ...     ...        ...        ...        ...        ...
# 4991   04:01   06:02      11:04      13:01      02:01      03:03
# 4992   12:02   07:02      14:05      11:04      03:03      06:01
# 4995   04:01   12:02      14:04      15:02      06:01      02:01
# 4997   06:02   15:02      13:02      07:01      02:01      03:03
# 4998   05:01   07:02      15:01      07:01      02:02      05:02
#
# [4526 rows x 13 columns]
# [Timing] Greedy solver execution: 268.8385 seconds
#
# === Solver Configuration ===
# Parallel mode: serial
# Num workers: 1
# Total samples: 5000
#
# [solver config]: {'max_iter': 15, 'top_n': 3, 'top_k_global': 3}
# [parallel config]: {'mode': 'serial', 'num_workers': 1}
# [data config]: {'dataset_path': '../data/simulated_HLA_samples_5000.csv', 'number_doubles': 0}
#
# === Results ===
#
# [HLASolver] Final best global filters:
# ['SIM_3100', 'SIM_1495', 'SIM_3665', 'SIM_3853', 'SIM_3448', 'SIM_1212', 'SIM_2694', 'SIM_4504', 'SIM_3538', 'SIM_4548', 'SIM_670', 'SIM_1425', 'SIM_168', 'SIM_2833', 'SIM_4075']
# [{'HLA-A': [98, 176], 'HLA-B': [227, 270], 'HLA-C': [1, 86], 'HLA-DQB': [96, 111], 'HLA-DRB': [1, 59]}, {'HLA-A': [12, 98], 'HLA-B': [227, 242], 'HLA-C': [30, 86], 'HLA-DQB': [27, 96], 'HLA-DRB': [28, 64]}, {'HLA-A': [9, 98], 'HLA-B': [227, 242], 'HLA-C': [28, 74], 'HLA-DQB': [111, 139], 'HLA-DRB': [2, 28]}, {'HLA-A': [7, 98], 'HLA-B': [118, 140], 'HLA-C': [1, 86], 'HLA-DQB': [96, 111], 'HLA-DRB': [2, 28]}, {'HLA-A': [0, 7], 'HLA-B': [74, 172], 'HLA-C': [43, 74], 'HLA-DQB': [0, 46], 'HLA-DRB': [27, 65]}, {'HLA-A': [12, 208], 'HLA-B': [140, 242], 'HLA-C': [1, 28], 'HLA-DQB': [96, 111], 'HLA-DRB': [1, 28]}, {'HLA-A': [0, 27], 'HLA-B': [74, 249], 'HLA-C': [65, 112], 'HLA-DQB': [73, 139], 'HLA-DRB': [27, 55]}, {'HLA-A': [12, 98], 'HLA-B': [140, 227], 'HLA-C': [1, 86], 'HLA-DQB': [111, 139], 'HLA-DRB': [3, 55]}, {'HLA-A': [98, 176], 'HLA-B': [227, 242], 'HLA-C': [28, 74], 'HLA-DQB': [96, 168], 'HLA-DRB': [27, 64]}, {'HLA-A': [7, 185], 'HLA-B': [74, 191], 'HLA-C': [73, 74], 'HLA-DQB': [139, 167], 'HLA-DRB': [27, 28]}, {'HLA-A': [7, 176], 'HLA-B': [86, 191], 'HLA-C': [65, 73], 'HLA-DQB': [0, 73], 'HLA-DRB': [8, 55]}, {'HLA-A': [0, 7], 'HLA-B': [213, 237], 'HLA-C': [43, 74], 'HLA-DQB': [27, 73], 'HLA-DRB': [27, 64]}, {'HLA-A': [98], 'HLA-B': [140, 270], 'HLA-C': [43, 74], 'HLA-DQB': [96, 111], 'HLA-DRB': [0, 28]}, {'HLA-A': [7, 176], 'HLA-B': [74, 139], 'HLA-C': [43, 65], 'HLA-DQB': [73, 118], 'HLA-DRB': [7, 65]}, {'HLA-A': [0, 27], 'HLA-B': [86, 236], 'HLA-C': [43, 65], 'HLA-DQB': [73, 139], 'HLA-DRB': [27, 66]}]
#                Region Population Sample ID HLA-A 1 HLA-A 2 HLA-B 1 HLA-B 2  \
# 0     North-East Asia    unknown     SIM_1   23:01   68:01   27:02   07:02
# 1     North-East Asia    unknown     SIM_2   03:01   01:01   08:01   07:02
# 2          South Asia    unknown     SIM_3   02:01   33:03   52:01   35:03
# 3          South Asia    unknown     SIM_4   68:01   01:01   49:01   07:02
# 4     South-East Asia   Oriental     SIM_5   33:03   33:03   51:01   13:01
# ...               ...        ...       ...     ...     ...     ...     ...
# 4991  North-East Asia    unknown  SIM_4992   01:01   02:01   13:02   44:02
# 4992       South Asia    unknown  SIM_4993   11:01   24:02   27:05   40:06
# 4995       South Asia    unknown  SIM_4996   33:03   01:01   35:01   15:17
# 4997       South Asia    unknown  SIM_4998   01:01   24:02   50:01   40:06
# 4998  North-East Asia    unknown  SIM_4999   02:01   03:01   35:01   41:02
#
#      HLA-C 1 HLA-C 2 HLA-DQB1 1 HLA-DQB1 2 HLA-DRB1 1 HLA-DRB1 2
# 0      07:02   01:02      03:01      01:01      03:01      05:01
# 1      07:01   01:02      04:02      14:04      02:02      05:01
# 2      15:02   04:01      12:02      11:01      06:01      02:02
# 3      15:02   07:02      11:01      07:01      05:03      06:01
# 4      14:02   08:01      09:01      15:01      06:01      03:02
# ...      ...     ...        ...        ...        ...        ...
# 4991   04:01   06:02      11:04      13:01      02:01      03:03
# 4992   12:02   07:02      14:05      11:04      03:03      06:01
# 4995   04:01   12:02      14:04      15:02      06:01      02:01
# 4997   06:02   15:02      13:02      07:01      02:01      03:03
# 4998   05:01   07:02      15:01      07:01      02:02      05:02
#
# [4526 rows x 13 columns]
# [Timing] HLASolver::run(): 269.7625 seconds

# %% [markdown]
# ---
# ## 6. Run Solver with Restart

# %%
import sys
import os

# Optional: import time if your run is long and you want timestamps
from datetime import datetime

class Tee:
    def __init__(self, *streams):
        self.streams = streams

    def write(self, message):
        for s in self.streams:
            s.write(message)
            s.flush()  # Ensure real-time logging

    def flush(self):
        for s in self.streams:
            s.flush()

# Set up project root path
project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))
if project_root not in sys.path:
    sys.path.insert(0, project_root)

from hla_solver import HLASolver

# Path to config file
config_path = os.path.join(project_root, "configs", "cover_serial_config.yaml")
solver = HLASolver(config_path)

# Define log file path
log_path = os.path.join(project_root, "console_output_serial_restart_test.log")

# Open log file and tee stdout to both console and log
with open(log_path, "w", encoding="utf-8") as logfile:
    tee = Tee(sys.stdout, logfile)
    sys.stdout = tee  # Override stdout
    try:
        best_filters = solver.run(restart_file="restarts/greedy_restart_20251016_180855.csv")
    finally:
        sys.stdout = sys.__stdout__  # Restore original stdout

# Final summary printed to notebook only
print("\nBest filters:", best_filters)

# %% [markdown]
# ---
# ## 6. Results

# %%
print("\nFinal best global filters:")
print( best_filters)

# %% [markdown]
# ---
# ## 7. Optional: Validation and Metrics

# %%
from hla_solver.validation import print_validation_report

print( df )
# Example: assuming best_filters contains sample indices or a structure from which you extract selected indices
selected_indices = ['SIM_44', 'SIM_52', 'SIM_8', 'SIM_17', 'SIM_41']
print_validation_report(df, hla_groups, selected_indices)

# %% [markdown]
# ---
# ## Validation
# - Create a small dataset
# - Find best single sample cover
# - Print best single sample cover and a tabular list of all samples that it covers to identify any incorrectness

# %%
# we now have data/simulated_HLA_samples_100.csv
# this has only 100 samples generated as per the reformat and generate function

# add path to modules to system path:

# Set up project root path
import os, sys
project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))
if project_root not in sys.path:
    sys.path.insert(0, project_root)

# Imports from your package
# from hla_solver import HLASolver
from hla_solver.selectors import find_top_covering_samples
from hla_solver.preprocessing import preprocess
from hla_solver.selectors import sample_coverage_percent
from hla_solver.selectors import find_matching_samples_by_filter
from hla_solver.utils import TimingLogger

# define data set
csv_path = "../data/simulated_HLA_samples_20000.csv"

# create timing logger:
timing_logger = TimingLogger(verbose=True)

# preprocess data set
df, hla_groups, allele_to_id, id_to_allele, allele_matrix, allele_id_to_positions, allele_columns, sample_allele_sets = preprocess( csv_path )
# from selectors import find_top_covering_samples, multi_sample_coverage_and_remainder
# def find_top_covering_samples(
#     df: pd.DataFrame,
#     hla_groups: List[Tuple[str, str, str]],
#     top_n: int,
#     allele_sets_by_sample: Dict[str, Dict[str, frozenset]],
#     coverage_type: str = "intersection",
#     verbose: bool = False
# ) -> List[Dict[str, Any]]:

top_samples = find_top_covering_samples(
    df=df,
    hla_groups=hla_groups,
    top_n=3, 
    allele_sets_by_sample=sample_allele_sets,
    allele_to_id=allele_to_id,
    verbose=True, 
    enable_timing=True,
    timing=timing_logger.timing,
)

print( top_samples )

# %%
import time
import pandas as pd

# Display more columns without wrapping
pd.set_option('display.max_columns', None)      # show all columns
pd.set_option('display.width', 2000)            # increase overall width
pd.set_option('display.max_colwidth', None)     # show full content of each column

print("\nTop Covering Samples:")
for sample in top_samples:
    print(sample)

# Pick the top sample
top_sample_id = top_samples[0]["Sample ID"]
top_sample_alleles = top_samples[0]["Alleles"]

print(f"\nTop Sample ID: {top_sample_id}")
print("Top Sample Alleles (by group):")
for group, alleles in top_sample_alleles.items():
    print(f"  {group}: {alleles}")

# Time the sample coverage computation
start_time = time.time()

coverage_pct, allele_dict = sample_coverage_percent(
    df=df,
    hla_groups=hla_groups,
    sample_id=top_sample_id,
    allele_sets_by_sample=sample_allele_sets,
    allele_to_id=allele_to_id,
    coverage_type="intersection",
    verbose=True
)

elapsed = time.time() - start_time
print(f"\n sample_coverage_percent executed in {elapsed:.4f} seconds.")

# print("\nCovered Sample IDs:", covered_sample_ids)

# %%
coverage_pct, allele_dict = sample_coverage_percent(
                df=df,
                hla_groups=hla_groups,
                sample_id=top_sample_id,
                allele_sets_by_sample=sample_allele_sets,
                allele_to_id=allele_to_id,
                coverage_type="intersection",
                verbose=True
            )

print( allele_dict )

# %%
from pprint import pprint

# Print first 2 entries from the dictionary
for i, (sample_id, allele_dict) in enumerate(sample_allele_sets.items()):
    if i >= 2:
        break
    print(f"Sample ID: {sample_id}")
    pprint(allele_dict)
    print()

# %%
print( list(sample_allele_sets['SIM_1']['HLA-A'])[0] )
